# %% [markdown]
# <!-- # DICTANARY📚📖 -->

# %%
user:dict = {
    "username": "Arsh",
    "age": 18,
    "city": "karachi",
    "roll_number": 501028
}

print(user["username"])
print(user["age"])
print(user["city"])
print(user["roll_number"])

user["age"] = 17
print(user)
# Out:
# Arsh
# 18
# karachi
# 501028
# {'username': 'Arsh', 'age': 17, 'city': 'karachi', 'roll_number': 501028}

# %% [markdown]
# <!-- # ADDING KEY VALUE IN PYTHON IN DICTANARY -->

# %%
user:dict = {
    "username": "Arsh",
    "age": 18,
    "city": "karachi",
    "roll_number": 501028
}

user["Gender"] = "male"
print(user)
# Out:
# {'username': 'Arsh', 'age': 18, 'city': 'karachi', 'roll_number': 501028, 'Gender': 'male'}

# %% [markdown]
# <!-- # LOOPS➿ -->

# %%
# how create loops in python
# for variable_name in (range)
#   block of code

# for a in range(1, 21):
#     print(a)

students = ["arsh" , "anus" , "rohan" , "mosa" , "abullrahman"]
for student in students:
    print(student)

print(students[0])
# Out:
# arsh
# anus
# rohan
# mosa
# abullrahman
# arsh

# %% [markdown]
# # GUESS THE NUMBER: ![image.png](attachment:image.png)

# %%
# guess the number

correct_number = 28
guess = 0

while guess != correct_number:
    guess = int(input("guess the number: "))
    print("Try agein please😌" if guess != correct_number else "U guess the correct number🥳")
# Out:
# Try agein please😌
# Try agein please😌
# Try agein please😌
# U guess the correct number🥳

# %% [markdown]
# # LIST📃 AND DICTANOARY📚 MIXTING

# %%
#            0     1       2        3       4     5      6         7  
student = ["arsh", 17, "karachi", 501028, "mosa", 17, "karachi", 205080]
# print(student)

users: dict = {
    "username": student[0],
    "age": student[1],
    "city": student[2],
    "roll_number": student[3],
    "username1": student[4],
    "age1": student[5],
    "city1": student[6],
    "roll_number1": student[7]
}

print(users)

print(users["username1"])
# Out:
# {'username': 'arsh', 'age': 17, 'city': 'karachi', 'roll_number': 501028, 'username1': 'mosa', 'age1': 17, 'city1': 'karachi', 'roll_number1': 205080}
# mosa

# %% [markdown]
# # finding exponent in python by loop \ diffenert between while loop and for loop.

# %%
numbers = [1, 2, 3, 4, 5]

for i in numbers:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
